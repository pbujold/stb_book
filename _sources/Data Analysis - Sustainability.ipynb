# %%
import datetime
print('Last Updated On: ', datetime.datetime.now())
print('Author: Philipe Bujold')
# Out:
# Last Updated On:  2022-12-01 07:51:42.513167
# Author: Philipe Bujold

# %%
import numpy as np
import pandas as pd
# pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import seaborn as sb 
cm = sb.diverging_palette(5, 250, as_cmap=True)

# import surveyAnalysis as survey #custom analysis scripts
import pyreadstat
import statsmodels.api as sm
from statsmodels.stats.weightstats import DescrStatsW

import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"
from plotly.subplots import make_subplots


from scipy.stats import pearsonr

import surveyAnalysis as survey

# %%
from itables import init_notebook_mode, show
# init_notebook_mode(all_interactive=False, connected=True)
import itables.options as opt
opt.column_filters = "footer"
opt.lengthMenu = [5, 10, 20, 50, 100, 200, 500]
# Out:
# c:\Anaconda\envs\pandas-profiling2\lib\site-packages\itables\javascript.py:63: UserWarning:
#
# Did you know? init_notebook_mode(all_interactive=False, connected=True) does nothing. Feel free to remove this line, or pass warn_if_call_is_superfluous=False.

# %%
spss1, meta = pyreadstat.read_sav(r"C:\Users\pbujold\Rare\Save the Bay - Documents\Data Analysis\spss.sav")#, apply_value_formats=True)
spss1_enriched = pyreadstat.set_value_labels(spss1, meta, formats_as_category=True, formats_as_ordered_category=True)
spss1_enriched['Recruitment'] = "Lucid"
meta.column_names_to_labels['Recruitment'] = 'Platform used to recruit participant'

spss2, meta2 = pyreadstat.read_sav(r"C:\Users\pbujold\Rare\Save the Bay - Documents\Data Analysis\spss2.sav")#, apply_value_formats=True)
spss2_enriched = pyreadstat.set_value_labels(spss2, meta2, formats_as_category=True, formats_as_ordered_category=True)
spss2_enriched['Recruitment'] = "QR Code"

df = pd.concat((spss1_enriched, spss2_enriched))

# %%
# Change to numeric variables
for col in ['var24', 'var69', 'var65', 'var212', 'var246', 'var127', 'var68', 'var62']:
    # print(df[col].unique())
    df[col] = df[col].apply(pd.to_numeric, errors='coerce')
        

# Change to unordered 
for col in ['var184', 'var187', 'var175', 'var188', 'var179', 'var185', 'var178', 'var177']:
    df[col] = df[col].astype("category").cat.as_unordered()

# Change to unordered 
for col in ['var9', 'var11', 'var16', 'var241', 'var152', 'var44', 'var85', 'Recruitment' ]:
    df[col] = df[col].astype("category").cat.as_unordered()

#filter for country (i.e. removing Phil's tests)

# df['VGeoCity'].value_counts()
# df['VGeoRegion'].value_counts()
# df['Vpostal'].value_counts()
df = df.loc[df['VGeoCountry'] == 'United States']
df = df.loc[df['var241'].notna()] #some answers don't have the town, probably early practice 
df = df.loc[~df['Vsessionid'].str.contains('test')] #remove any "test" entries

def validateZip(data):
    if data['var16'] == "02842":
        return data['var241'] == "Middletown"
    elif data['var16'] == "02840" or data['var16'] == "02841":
        return data['var241'] == "Newport"
    elif data['var16'] == "02871":
        return data['var241'] == "Portsmouth"
    else:
        return False

df['Valid ZipTown'] = df[['var16', 'var241']].apply(validateZip, axis=1)
meta.column_names_to_labels['Valid ZipTown'] = "Does the respondent's Zip Code match with the town they say they live?"

for col in ['var108', 'var109', 'var110', 'var111', 'var112', 'var113', 'var114', 'var115', 'var116', 'var117', 'var118', 'var119']: 
    df[col] = df[col].replace('I dont know', np.nan)

# %% [markdown]
# ## 4.  Sustainable Fertilization
# ----

# %% [markdown]
# Social stuff

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Pie(labels=df[['var211']].value_counts().index, values=df[['var211']].value_counts().values, textinfo='label+percent')])
fig.update_layout(
width=1000,
height=450,
title={
    "text": meta.column_names_to_labels['var211'],
    "x": 0.5,
    "xanchor": "center",
    "font": dict(
                family="Arial",
                size=12,
            ),
    },
# xaxis_tickangle=45,  # , "x": 0.5, "xanchor": "center"},
)

fig.show()
# Out:
# <div>                            <div id="d8fe2bb0-986b-4969-9a2e-ae52d15c3055" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8fe2bb0-986b-4969-9a2e-ae52d15c3055")) {                    Plotly.newPlot(                        "d8fe2bb0-986b-4969-9a2e-ae52d15c3055",                        [{"labels":[["Yes"],["No"]],"textinfo":"label+percent","values":[17,8],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3 ...
#
# var gd = document.getElementById('d8fe2bb0-986b-4969-9a2e-ae52d15c3055');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = wi

# %%
carePlot = survey.plot_single_proportions_2( df[[
'var126',
  'var124',
 ]],
                                                 meta,
                                                 orientation='v')
# Out:
# <div>                            <div id="85ebdeff-999d-4af1-b487-ac03520bd997" class="plotly-graph-div" style="height:600px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85ebdeff-999d-4af1-b487-ac03520bd997")) {                    Plotly.newPlot(                        "85ebdeff-999d-4af1-b487-ac03520bd997",                        [{"alignmentgroup":"True","customdata":[["Benefits me a lot",13]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var126"],"legendgroup":"Benefits me a lot","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"Benefits me a lot","offsetgroup":"Benefits me a lot","orientation":"v","showlegend":true,"textposition":"auto","x":["How much do you think fertilizing your lawn sustainably<br>would benefit you, personally?"],"xaxis":"x","y":[27.083],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Benefits me",11]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var126"],"legendgroup":"Benefits me","marker":{"color":"#9ab7cd","pattern":{"shape":""}},"name":"Benefits me","offsetgroup":"Benefits me","orientation":"v","showlegend":true,"textposition":"auto","x":["How much do you think fertilizing your lawn sustainably<br>would benefit you, personally?"],"xaxis":"x","y":[22.917],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Moderately benefits me",14]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var126"],"legendgroup":"Moderately benefits me","marker":{"color":"#f2f1f1","pattern":{"shape":""}},"name":"Moderately benefits me","offsetgroup":"Moderately benefits me","orientation":"v","showlegend":true,"textposition":"auto","x":["How much do you think fertilizing your lawn sustainably<br>would benefit you, personally?"],"xaxis":"x","y":[29.167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Benefits me slightly",7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var126"],"legendgroup":"Benefits me slightly","marker":{"color":"#e6959b","pattern":{"shape":""}},"name":"Benefits me slightly","offsetgroup":"Benefits me slightly","orientation":"v","showlegend":true,"textposition":"auto","x":["How much do you think fertilizing your lawn sustainably<br>would benefit you, personally?"],"xaxis":"x","y":[14.583],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["No benefits for me at all",3]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var126"],"legendgroup":"No benefits for me at all","marker":{"color":"#da3b46","pattern":{"shape":""}},"name":"No benefits for me at all","offsetgroup":"No benefits for me at all","orientation":"v","showlegend":true,"textposition":"auto","x":["How much do you think fertilizing your lawn sustainably<br>would benefit you, personally?"],"xaxis":"x","y":[6.25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["No",7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var124"],"legendgroup":"No","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Before taking this survey, had you ever considered<br>fertilizing your lawn su ...

# %%
carePlot = survey.plot_single_proportions_2( df[[
'var137',
'var138',
'var139',
'var140',
'var141',
'var209',
'var237',
'var238',
'var243',
 ]],
                                                 meta,
                                                 orientation='h')

carePlot = survey.plot_single_proportions_2( df[[
'var231',
'var232',
'var236',
'var234',
'var233',
'var235',
'var239',
'var240',
'var244',
 ]],
                                                 meta,
                                                 orientation='h')
# Out:
# <div>                            <div id="e3174dae-61ec-48e6-9b19-b6885d093df7" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3174dae-61ec-48e6-9b19-b6885d093df7")) {                    Plotly.newPlot(                        "e3174dae-61ec-48e6-9b19-b6885d093df7",                        [{"alignmentgroup":"True","customdata":[["Very likely",4],["Very likely",6],["Very likely",4],["Very likely",9],["Very likely",4],["Very likely",6],["Very likely",6],["Very likely",7],["Very likely",5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var243","var238","var237","var209","var141","var140","var139","var138","var137"],"legendgroup":"Very likely","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"Very likely","offsetgroup":"Very likely","orientation":"h","showlegend":true,"textposition":"auto","x":[8.333,12.5,8.333,18.75,8.333,12.5,12.5,14.583,10.417],"xaxis":"x","y":["Time savings","Opportunities for recreational activities (swimming,<br>fishing, etc )","Drinking water quality","Appearance of your lawn","Money savings","Biodiversity on Aquidneck Island","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Likely",3],["Likely",4],["Likely",8],["Likely",6],["Likely",6],["Likely",4],["Likely",7],["Likely",6],["Likely",4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var243","var238","var237","var209","var141","var140","var139","var138","var137"],"legendgroup":"Likely","marker":{"color":"#9ab7cd","pattern":{"shape":""}},"name":"Likely","offsetgroup":"Likely","orientation":"h","showlegend":true,"textposition":"auto","x":[6.25,8.333,16.667,12.5,12.5,8.333,14.583,12.5,8.333],"xaxis":"x","y":["Time savings","Opportunities for recreational activities (swimming,<br>fishing, etc )","Drinking water quality","Appearance of your lawn","Money savings","Biodiversity on Aquidneck Island","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Neither likely nor unlikely",8],["Neither likely nor unlikely",5],["Neither likely nor unlikely",3],["Neither likely nor unlikely",1],["Neither likely nor unlikely",1],["Neither likely nor unlikely",4],["Neither likely nor unlikely",3],["Neither likely nor unlikely",3],["Neither likely nor unlikely",6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var243","var238","var237","var209","var141","var140","var139","var138","var137"],"legendgroup":"Neither likely nor unlikely","marker":{"color":"#f2f1f1","pattern":{"shape":""}},"name":"Neither likely nor unlikely","offsetgroup":"Neither likely nor unlikely","orientation":"h","showlegend":true,"textposition":"auto","x":[16.667,10.417,6.25,2.083,2.083,8.333,6.25,6.25,12.5],"xaxis":"x","y":["Time savings","Opportunities for recreational activities (swimming,<br>fishing, etc )","Drinking water quality","Appearance of your lawn","Money savings","Biodiversity on Aquidneck Island","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Unlikely",1],["Unlikely",2],["Unlikely",1],["Unlikely",5],["Unlikely",3],["Unlikely",1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}< ...
# <div>                            <div id="370d89ec-8e28-4734-af77-e32701a04b19" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("370d89ec-8e28-4734-af77-e32701a04b19")) {                    Plotly.newPlot(                        "370d89ec-8e28-4734-af77-e32701a04b19",                        [{"alignmentgroup":"True","customdata":[["Very likely",2],["Very likely",1],["Very likely",2],["Very likely",2],["Very likely",1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var240","var236","var233","var232","var231"],"legendgroup":"Very likely","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"Very likely","offsetgroup":"Very likely","orientation":"h","showlegend":true,"textposition":"auto","x":[4.167,2.083,4.167,4.167,2.083],"xaxis":"x","y":["Drinking water quality","Appearance of your lawn","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Likely",2],["Likely",3],["Likely",2],["Likely",3],["Likely",2],["Likely",5],["Likely",3],["Likely",4],["Likely",5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var244","var240","var239","var236","var235","var234","var233","var232","var231"],"legendgroup":"Likely","marker":{"color":"#9ab7cd","pattern":{"shape":""}},"name":"Likely","offsetgroup":"Likely","orientation":"h","showlegend":true,"textposition":"auto","x":[4.167,6.25,4.167,6.25,4.167,10.417,6.25,8.333,10.417],"xaxis":"x","y":["Time savings for your household","Drinking water quality","Opportunities for recreational activities (swimming,<br>fishing, etc )","Appearance of your lawn","Money savings for your household","Biodiversity on Aquidneck Island","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Neither likely nor unlikely",2],["Neither likely nor unlikely",2],["Neither likely nor unlikely",5],["Neither likely nor unlikely",1],["Neither likely nor unlikely",3],["Neither likely nor unlikely",2],["Neither likely nor unlikely",2],["Neither likely nor unlikely",1],["Neither likely nor unlikely",1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var244","var240","var239","var236","var235","var234","var233","var232","var231"],"legendgroup":"Neither likely nor unlikely","marker":{"color":"#f2f1f1","pattern":{"shape":""}},"name":"Neither likely nor unlikely","offsetgroup":"Neither likely nor unlikely","orientation":"h","showlegend":true,"textposition":"auto","x":[4.167,4.167,10.417,2.083,6.25,4.167,4.167,2.083,2.083],"xaxis":"x","y":["Time savings for your household","Drinking water quality","Opportunities for recreational activities (swimming,<br>fishing, etc )","Appearance of your lawn","Money savings for your household","Biodiversity on Aquidneck Island","Narragansett Bay water quality","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1],["Very Unlikely",1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var244","var240","var239","var236","var235","var234","var233","var232", ...

# %% [markdown]
# Social Norms and Reference Network

# %%
carePlot = survey.plot_single_proportions_2( df[[
  'var212', 'var127', 'var246', 
 ]],
                                                 meta,
                                                 orientation='v')

carePlot = survey.plot_single_proportions_2( df[[
'var132',
'var129',
'var131'

 ]],
                                                 meta,
                                                 orientation='v')


carePlot = survey.plot_single_proportions_2( df[[
'var145', 'var146', 'var147', 'var148','var149','var151','var245',
 ]],
                                                 meta,
                                                 orientation='h')
# Out:
# <div>                            <div id="54dcd767-9d43-4d56-adce-2a8865599310" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54dcd767-9d43-4d56-adce-2a8865599310")) {                    Plotly.newPlot(                        "54dcd767-9d43-4d56-adce-2a8865599310",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"<b>%{hovertext}</b><br><br>Question_name=%{x}<br>value=%{y}<extra></extra>","hovertext":["var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246","var246"],"legendgroup":"","marker":{"color":"black"},"name":"","offsetgroup":"","orientation":"v","points":"all","scalegroup":"True","showlegend":false,"x":["How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you and your household have to<br>put into fertilizing sustainably compared to the<br>alternative?","How much effort would you  ...
# <div>                            <div id="a5648ae8-96ea-4431-95e6-6f98e3ed9493" class="plotly-graph-div" style="height:600px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5648ae8-96ea-4431-95e6-6f98e3ed9493")) {                    Plotly.newPlot(                        "a5648ae8-96ea-4431-95e6-6f98e3ed9493",                        [{"alignmentgroup":"True","customdata":[["8",2],["8",4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var132","var131"],"legendgroup":"8","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"8","offsetgroup":"8","orientation":"v","showlegend":true,"textposition":"auto","x":["Imagine 10 households in your community  If you had to<br>guess, how many of them do you think are trying to<br>fertilize their lawn sustainably?","Imagine 10 households in your community  If you had to<br>guess, how many think that people should fertilize<br>their lawns sustainably?"],"xaxis":"x","y":[4.167,8.333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["7",4],["7",6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var132","var131"],"legendgroup":"7","marker":{"color":"#6896b8","pattern":{"shape":""}},"name":"7","offsetgroup":"7","orientation":"v","showlegend":true,"textposition":"auto","x":["Imagine 10 households in your community  If you had to<br>guess, how many of them do you think are trying to<br>fertilize their lawn sustainably?","Imagine 10 households in your community  If you had to<br>guess, how many think that people should fertilize<br>their lawns sustainably?"],"xaxis":"x","y":[8.333,12.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["6",7],["6",11]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var132","var131"],"legendgroup":"6","marker":{"color":"#8eb0c8","pattern":{"shape":""}},"name":"6","offsetgroup":"6","orientation":"v","showlegend":true,"textposition":"auto","x":["Imagine 10 households in your community  If you had to<br>guess, how many of them do you think are trying to<br>fertilize their lawn sustainably?","Imagine 10 households in your community  If you had to<br>guess, how many think that people should fertilize<br>their lawns sustainably?"],"xaxis":"x","y":[14.583,22.917],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["5",6],["5",8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var132","var131"],"legendgroup":"5","marker":{"color":"#b7cbda","pattern":{"shape":""}},"name":"5","offsetgroup":"5","orientation":"v","showlegend":true,"textposition":"auto","x":["Imagine 10 households in your community  If you had to<br>guess, how many of them do you think are trying to<br>fertilize their lawn sustainably?","Imagine 10 households in your community  If you had to<br>guess, how many think that people should fertilize<br>their lawns sustainably?"],"xaxis":"x","y":[12.5,16.667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["4",8],["4",2]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Question_name=%{x}<br>Percentage=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var132","var131"],"legendgroup":"4","marker":{"color":"#dde4ea","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"textposition":"auto","x":["Imagine 10 households in your community  If you had to<br>guess, how many of them do ...
# <div>                            <div id="58caf563-2a83-4021-8212-05f93a9f625d" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58caf563-2a83-4021-8212-05f93a9f625d")) {                    Plotly.newPlot(                        "58caf563-2a83-4021-8212-05f93a9f625d",                        [{"alignmentgroup":"True","customdata":[["Very likely",6],["Very likely",13],["Very likely",8],["Very likely",13],["Very likely",18],["Very likely",17],["Very likely",14]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var245","var151","var149","var148","var147","var146","var145"],"legendgroup":"Very likely","marker":{"color":"#417ca8","pattern":{"shape":""}},"name":"Very likely","offsetgroup":"Very likely","orientation":"h","showlegend":true,"textposition":"auto","x":[12.5,27.083,16.667,27.083,37.5,35.417,29.167],"xaxis":"x","y":["Time savings for your household","Appearance of your community's lawns","Money savings for your household","Biodiversity on Aquidneck Island","Health of Narragansett Bay","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Likely",11],["Likely",22],["Likely",13],["Likely",21],["Likely",22],["Likely",15],["Likely",18]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var245","var151","var149","var148","var147","var146","var145"],"legendgroup":"Likely","marker":{"color":"#9ab7cd","pattern":{"shape":""}},"name":"Likely","offsetgroup":"Likely","orientation":"h","showlegend":true,"textposition":"auto","x":[22.917,45.833,27.083,43.75,45.833,31.25,37.5],"xaxis":"x","y":["Time savings for your household","Appearance of your community's lawns","Money savings for your household","Biodiversity on Aquidneck Island","Health of Narragansett Bay","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Neither likely nor unlikely",24],["Neither likely nor unlikely",7],["Neither likely nor unlikely",12],["Neither likely nor unlikely",9],["Neither likely nor unlikely",4],["Neither likely nor unlikely",11],["Neither likely nor unlikely",11]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var245","var151","var149","var148","var147","var146","var145"],"legendgroup":"Neither likely nor unlikely","marker":{"color":"#f2f1f1","pattern":{"shape":""}},"name":"Neither likely nor unlikely","offsetgroup":"Neither likely nor unlikely","orientation":"h","showlegend":true,"textposition":"auto","x":[50.0,14.583,25.0,18.75,8.333,22.917,22.917],"xaxis":"x","y":["Time savings for your household","Appearance of your community's lawns","Money savings for your household","Biodiversity on Aquidneck Island","Health of Narragansett Bay","Health of your community","Health of your family and friends"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Unlikely",3],["Unlikely",3],["Unlikely",7],["Unlikely",3],["Unlikely",2],["Unlikely",2],["Unlikely",2]],"hovertemplate":"<b>%{hovertext}</b><br><br>Answer=%{customdata[0]}<br>Percentage=%{x}<br>Question_name=%{y}<br>Count=%{customdata[1]}<extra></extra>","hovertext":["var245","var151","var149","var148","var147","var146","var145"],"legendgroup":"Unlikely","marker":{"color":"#e6959b","pattern":{"shape":""}},"name":"Unlikely","offsetgroup":"Unlikely","orientation":"h","showlegend":true,"textposition":"auto","x":[6.25,6.25,14.583,6.25,4.167,4.167,4.167],"xaxis":"x"," ...
